# %%
import pandas as pd
import joblib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append("../..")

import src.indicators.leavitt_indicator as lu

# %% [markdown]
# ### 🔹 Step 1: Load the Test Dataset
# - Ensure the dataset contains the same features used during training.

# %%
# Load test dataset
test_data_path = "../data/Predict_EUR_USD_D.csv"  # Adjust path as needed
df_analyze = pd.read_csv(test_data_path)

# Display sample data
print(df_analyze.tail(1))
print(df_analyze.shape)
# Out:
#       Unnamed: 0                       time  volume    mid_o    mid_h   mid_l  \
# 1846        1846  2025-02-11 22:00:00-05:00   55878  1.03612  1.03858  1.0354
#
#         mid_c    bid_o   bid_h    bid_l    bid_c    ask_o    ask_h    ask_l  \
# 1846  1.03737  1.03604  1.0385  1.03532  1.03729  1.03621  1.03865  1.03548
#
#         ask_c
# 1846  1.03745
# (1847, 15)

# %% [markdown]
# ✅ Now, we have predict test dataset loaded.
#
# ---

# %% [markdown]
# ### 🔹 Step 2: Extract lookback
#
# - Now, grab the data we are interest in for our lookback analysis
#
#
# ---

# %%
lookback = 100

# Select the last lookback number of rows from the dataset
df_lookback = df_analyze.tail(lookback).copy()

# Convert the 'time' column to datetime format for proper analysis
df_lookback["time"] = pd.to_datetime(df_lookback["time"])

print(df_lookback.tail(1))
print(df_lookback.shape)
# Out:
#       Unnamed: 0                      time  volume    mid_o    mid_h   mid_l  \
# 1846        1846 2025-02-11 22:00:00-05:00   55878  1.03612  1.03858  1.0354
#
#         mid_c    bid_o   bid_h    bid_l    bid_c    ask_o    ask_h    ask_l  \
# 1846  1.03737  1.03604  1.0385  1.03532  1.03729  1.03621  1.03865  1.03548
#
#         ask_c
# 1846  1.03745
# (100, 15)

# %%
df_lookback.to_csv("../data/lookback_data.csv", index=True)
print("✅ File saved successfully.")
# Out:
# ✅ File saved successfully.

# %% [markdown]
# ### 🔹 Step 3: Run it through data ingestion
#
# - Compute all the features
#
#
# ---

# %%
from src.services.data_ingestion_service import DataIngestionService

ingestion_service = DataIngestionService()
# Apply preprocessing (renaming, dropping unnecessary columns)
df_cleaned = ingestion_service.preprocess_data(df_lookback)
# Out:
# [ 2025-02-14 04:46:24,076 ] INFO [src.services.data_ingestion_service:49] - Converted 'time' column to 'Date' with datetime format.
# [ 2025-02-14 04:46:24,077 ] INFO [src.services.data_ingestion_service:67] - Dropped bid and ask price columns.
# [ 2025-02-14 04:46:24,077 ] INFO [src.services.data_ingestion_service:80] - Renamed mid-price columns to OHLC format.
# [ 2025-02-14 04:46:24,078 ] INFO [src.services.data_ingestion_service:85] - Dropped 'Unnamed: 0' index column.
# [ 2025-02-14 04:46:24,078 ] INFO [src.services.data_ingestion_service:93] - Set index to Date with unique timestamps.
# [ 2025-02-14 04:46:24,079 ] INFO [src.services.data_ingestion_service:95] - Processing leavitt data.
# [ 2025-02-14 04:46:24,089 ] INFO [src.services.data_ingestion_service:97] - Finished leavitt data.
# [ 2025-02-14 04:46:24,089 ] INFO [src.services.data_ingestion_service:99] - Processing indicators.
# [ 2025-02-14 04:46:24,091 ] INFO [src.services.data_ingestion_service:101] - Finished indicators.
# [ 2025-02-14 04:46:24,092 ] INFO [src.services.data_ingestion_service:103] - Processing target.
# [ 2025-02-14 04:46:24,093 ] INFO [src.services.data_ingestion_service:105] - Finished target.
# [ 2025-02-14 04:46:24,094 ] INFO [src.services.data_ingestion_service:112] - Dropped NaNs from all columns except Target_T+* fields.
# [ 2025-02-14 04:46:24,095 ] INFO [src.services.data_ingestion_service:117] - [Data Preprocessing] Input Data Shape: (78, 29)
# [ 2025-02-14 04:46:24,096 ] INFO [src.services.data_ingestion_service:118] - [Data Preprocessing] Checking for NaNs: 0 NaNs found

# %%
print(df_cleaned.shape)
print(df_cleaned.describe())
print(df_cleaned.columns)
# Out:
# (78, 29)
#               Volume       Open       High        Low      Close       AHMA  \
# count      78.000000  78.000000  78.000000  78.000000  78.000000  78.000000
# mean   158979.858974   1.050034   1.053723   1.045359   1.049511   1.049304
# std     48031.345766   0.017334   0.017146   0.017282   0.017086   0.016844
# min     55878.000000   1.024340   1.025010   1.017790   1.024340   1.025912
# 25%    132557.750000   1.037985   1.042588   1.034203   1.037497   1.037979
# 50%    160770.500000   1.048200   1.052290   1.041620   1.047060   1.046549
# 75%    178745.500000   1.056715   1.059658   1.052647   1.056607   1.053758
# max    398838.000000   1.092970   1.093740   1.087260   1.092970   1.088000
#
#        Leavitt_Projection  Leavitt_Convolution   LC_Slope  LC_Intercept  ...  \
# count           78.000000            78.000000  78.000000     78.000000  ...
# mean             1.048633             1.048046  -0.000582      1.049792  ...
# std              0.017553             0.017992   0.002610      0.018001  ...
# min              1.024600             1.024073  -0.007657      1.024216  ...
# 25%              1.035271             1.033832  -0.001739      1.036387  ...
# 50%              1.045268             1.044582  -0.000582      1.045447  ...
# 75%              1.055039             1.056008   0.001053      1.055633  ...
# max              1.088157             1.090368   0.004838      1.088485  ...
#
#        Returns_T-10  Momentum_T-10  Returns_T-21  Momentum_T-21       Hour  \
# count     78.000000      78.000000     78.000000      78.000000  78.000000
# mean      -0.000612       0.000129     -0.001029       0.000547  21.910256
# std        0.004969       0.007594      0.004641       0.007481   0.287664
# min       -0.018363      -0.016826     -0.018363      -0.018900  21.000000
# 25%       -0.002931      -0.005265     -0.003191      -0.004575  22.000000
# 50%       -0.001067       0.001223     -0.001428      -0.000166  22.000000
# 75%        0.001984       0.005245      0.001422       0.004609  22.000000
# max        0.014136       0.017616      0.007867       0.027661  22.000000
#
#        Day_Of_Week      Month         Year        ATR  Movement_Class
# count    78.000000  78.000000    78.000000  78.000000       78.000000
# mean      2.435897   7.435897  2024.384615   0.008150        0.961538
# std       2.086380   4.948015     0.489653   0.001232        0.763490
# min       0.000000   1.000000  2024.000000   0.005150        0.000000
# 25%       1.000000   1.000000  2024.000000   0.007729        0.000000
# 50%       2.000000  11.000000  2024.000000   0.008494        1.000000
# 75%       3.000000  12.000000  2025.000000   0.008896        2.000000
# max       6.000000  12.000000  2025.000000   0.010474        2.000000
#
# [8 rows x 29 columns]
# Index(['Volume', 'Open', 'High', 'Low', 'Close', 'AHMA', 'Leavitt_Projection',
#        'Leavitt_Convolution', 'LC_Slope', 'LC_Intercept', 'LC_Acceleration',
#        'Convolution_Probability', 'Returns', 'Returns_T-1', 'Momentum_T-1',
#        'Returns_T-2', 'Momentum_T-2', 'Returns_T-5', 'Momentum_T-5',
#        'Returns_T-10', 'Momentum_T-10', 'Returns_T-21', 'Momentum_T-21',
#        'Hour', 'Day_Of_Week', 'Month', 'Year', 'ATR', 'Movement_Class'],
#       dtype='object')

# %% [markdown]
# #### What is the last record??
#
# - It should be the record that we will be predicting

# %%
df_cleaned.tail(1)
# Out:
#                            Volume     Open     High     Low    Close  \
# Date
# 2025-02-11 22:00:00-05:00   55878  1.03612  1.03858  1.0354  1.03737
#
#                                AHMA  Leavitt_Projection  Leavitt_Convolution  \
# Date
# 2025-02-11 22:00:00-05:00  1.034488            1.032559             1.032416
#
#                            LC_Slope  LC_Intercept  ...  Returns_T-10  \
# Date                                               ...
# 2025-02-11 22:00:00-05:00 -0.000013      1.032455  ...     -0.001026
#
#                            Momentum_T-10  Returns_T-21  Momentum_T-21  Hour  \
# Date
# 2025-02-11 22:00:00-05:00       0.002232      0.006326       -0.00512    22
#
#                            Day_Of_Week  Month  Year       ATR  Movement_Class
# Date
# 2025-02-11 22:00:00-05:00            1      2  2025  0.007814               1
#
# [1 rows x 29 columns]

# %% [markdown]
# #### Verify ATR

# %%
from src.indicators.atr import calculate_atr

df_analysis = df_cleaned.copy()

# Apply EMA to True Range to calculate ATR
df_analysis["ATR_Computed_EMA"] = calculate_atr(df_analysis, 14)

# Extract ATR from the dataset for comparison
df_analysis["ATR_Dataset"] = df_cleaned["ATR"]  # Assuming ATR column exists in dataset

# %%
df_analysis[["ATR_Computed_EMA", "ATR_Dataset"]].tail(50)
# Out:
#                            ATR_Computed_EMA  ATR_Dataset
# Date
# 2024-12-02 22:00:00-05:00          0.008905     0.008917
# 2024-12-03 22:00:00-05:00          0.008676     0.008687
# 2024-12-04 22:00:00-05:00          0.008609     0.008618
# 2024-12-05 22:00:00-05:00          0.008629     0.008637
# 2024-12-08 22:00:00-05:00          0.008308     0.008315
# 2024-12-09 22:00:00-05:00          0.008131     0.008137
# 2024-12-10 22:00:00-05:00          0.007836     0.007841
# 2024-12-11 22:00:00-05:00          0.007687     0.007692
# 2024-12-12 22:00:00-05:00          0.007610     0.007614
# 2024-12-15 22:00:00-05:00          0.007265     0.007268
# 2024-12-16 22:00:00-05:00          0.007032     0.007035
# 2024-12-17 22:00:00-05:00          0.008348     0.008350
# 2024-12-18 22:00:00-05:00          0.008233     0.008236
# 2024-12-19 22:00:00-05:00          0.008530     0.008532
# 2024-12-22 22:00:00-05:00          0.008218     0.008220
# 2024-12-23 22:00:00-05:00          0.007483     0.007484
# 2024-12-25 22:00:00-05:00          0.007010     0.007011
# 2024-12-26 22:00:00-05:00          0.006594     0.006595
# 2024-12-29 22:00:00-05:00          0.006870     0.006871
# 2024-12-30 22:00:00-05:00          0.007028     0.007029
# 2025-01-01 22:00:00-05:00          0.008115     0.008116
# 2025-01-02 22:00:00-05:00          0.007700     0.007700
# 2025-01-05 22:00:00-05:00          0.008559     0.008559
# 2025-01-06 22:00:00-05:00          0.008683     0.008683
# 2025-01-07 22:00:00-05:00          0.008652     0.008652
# 2025-01-08 22:00:00-05:00          0.008005     0.008005
# 2025-01-09 22:00:00-05:00          0.008260     0.008260
# 2025-01-12 22:00:00-05:00          0.008121     0.008122
# 2025-01-13 22:00:00-05:00          0.007973     0.007974
# 2025-01-14 22:00:00-05:00          0.008197     0.008197
# 2025-01-15 22:00:00-05:00          0.007829     0.007829
# 2025-01-16 22:00:00-05:00          0.007659     0.007659
# 2025-01-19 22:00:00-05:00          0.008879     0.008879
# 2025-01-20 22:00:00-05:00          0.008947     0.008947
# 2025-01-21 22:00:00-05:00          0.008623     0.008624
# 2025-01-22 22:00:00-05:00          0.008352     0.008352
# 2025-01-23 22:00:00-05:00          0.008704     0.008704
# 2025-01-26 22:00:00-05:00          0.008602     0.008602
# 2025-01-27 22:00:00-05:00          0.008525     0.008525
# 2025-01-28 22:00:00-05:00          0.008207     0.008207
# 2025-01-29 22:00:00-05:00          0.008200     0.008200
# 2025-01-30 22:00:00-05:00          0.008227     0.008227
# 2025-02-02 22:00:00-05:00          0.009131     0.009131
# 2025-02-03 22:00:00-05:00          0.009458     0.009458
# 2025-02-04 22:00:00-05:00          0.009178     0.009178
# 2025-02-05 22:00:00-05:00          0.008666     0.008666
# 2025-02-06 22:00:00-05:00          0.008954     0.008954
# 2025-02-09 22:00:00-05:00          0.008464     0.008464
# 2025-02-10 22:00:00-05:00          0.008527     0.008527
# 2025-02-11 22:00:00-05:00          0.007814     0.007814

# %% [markdown]
# #### Verify Adaptive HMA

# %%
df_ahma = df_cleaned.copy()
ahma_period = 9

df_ahma["AHMA_Computed"] = lu.adaptive_hull_moving_average(df_ahma["Close"], ahma_period)
# Extract ATR from the dataset for comparison
df_ahma["AHMA_Dataset"] = df_cleaned["AHMA"]  # Assuming ATR column exists in dataset

# %%
df_ahma[["AHMA_Computed", "AHMA_Dataset"]]
# Out:
#                            AHMA_Computed  AHMA_Dataset
# Date
# 2024-10-23 21:00:00-05:00       1.082790      1.078503
# 2024-10-24 21:00:00-05:00       1.081839      1.078226
# 2024-10-27 21:00:00-05:00       1.081327      1.078478
# 2024-10-28 21:00:00-05:00       1.081264      1.079085
# 2024-10-29 21:00:00-05:00       1.082496      1.080851
# ...                                  ...           ...
# 2025-02-05 22:00:00-05:00       1.038044      1.038044
# 2025-02-06 22:00:00-05:00       1.036377      1.036377
# 2025-02-09 22:00:00-05:00       1.034043      1.034043
# 2025-02-10 22:00:00-05:00       1.033742      1.033742
# 2025-02-11 22:00:00-05:00       1.034488      1.034488
#
# [78 rows x 2 columns]

# %% [markdown]
# #### Verify Leavitt

# %%
df_leavitt = df_cleaned.copy()

# Apply Feature Engineering using AHMA as input instead of Close
plength = 9  # Projection lookback period
clength = 3  # Convolution lookback period

df_leavitt["Leavitt_Projection_Computed"] = lu.leavitt_projection(df_leavitt["AHMA"], plength)

(
    df_leavitt["Leavitt_Convolution_Computed"],
    df_leavitt["LC_Slope_Computed"],
    df_leavitt["LC_Intercept_Computed"],
) = lu.leavitt_convolution(df_leavitt["AHMA"], plength, clength)

df_leavitt["Leavitt_Projection_Dataset"] = df_cleaned["Leavitt_Projection"]
df_leavitt["Leavitt_Convolution_Dataset"] = df_cleaned["Leavitt_Convolution"]
df_leavitt["LC_Slope_Dataset"] = df_cleaned["LC_Slope"]
df_leavitt["LC_Intercept_Dataset"] = df_cleaned["LC_Intercept"]

# %%
df_leavitt[["Leavitt_Projection_Computed", "Leavitt_Projection_Dataset"]]
# Out:
#                            Leavitt_Projection_Computed  \
# Date
# 2024-10-23 21:00:00-05:00                     1.087959
# 2024-10-24 21:00:00-05:00                     1.087959
# 2024-10-27 21:00:00-05:00                     1.087959
# 2024-10-28 21:00:00-05:00                     1.087959
# 2024-10-29 21:00:00-05:00                     1.087959
# ...                                                ...
# 2025-02-05 22:00:00-05:00                     1.034700
# 2025-02-06 22:00:00-05:00                     1.033670
# 2025-02-09 22:00:00-05:00                     1.032585
# 2025-02-10 22:00:00-05:00                     1.032182
# 2025-02-11 22:00:00-05:00                     1.032559
#
#                            Leavitt_Projection_Dataset
# Date
# 2024-10-23 21:00:00-05:00                    1.075802
# 2024-10-24 21:00:00-05:00                    1.075383
# 2024-10-27 21:00:00-05:00                    1.075637
# 2024-10-28 21:00:00-05:00                    1.076432
# 2024-10-29 21:00:00-05:00                    1.077918
# ...                                               ...
# 2025-02-05 22:00:00-05:00                    1.034700
# 2025-02-06 22:00:00-05:00                    1.033670
# 2025-02-09 22:00:00-05:00                    1.032585
# 2025-02-10 22:00:00-05:00                    1.032182
# 2025-02-11 22:00:00-05:00                    1.032559
#
# [78 rows x 2 columns]

# %%
df_leavitt[["Leavitt_Projection_Computed", "Leavitt_Projection_Dataset"]]
# Out:
#                            Leavitt_Projection_Computed  \
# Date
# 2024-10-23 21:00:00-05:00                     1.087959
# 2024-10-24 21:00:00-05:00                     1.087959
# 2024-10-27 21:00:00-05:00                     1.087959
# 2024-10-28 21:00:00-05:00                     1.087959
# 2024-10-29 21:00:00-05:00                     1.087959
# ...                                                ...
# 2025-02-05 22:00:00-05:00                     1.034700
# 2025-02-06 22:00:00-05:00                     1.033670
# 2025-02-09 22:00:00-05:00                     1.032585
# 2025-02-10 22:00:00-05:00                     1.032182
# 2025-02-11 22:00:00-05:00                     1.032559
#
#                            Leavitt_Projection_Dataset
# Date
# 2024-10-23 21:00:00-05:00                    1.075802
# 2024-10-24 21:00:00-05:00                    1.075383
# 2024-10-27 21:00:00-05:00                    1.075637
# 2024-10-28 21:00:00-05:00                    1.076432
# 2024-10-29 21:00:00-05:00                    1.077918
# ...                                               ...
# 2025-02-05 22:00:00-05:00                    1.034700
# 2025-02-06 22:00:00-05:00                    1.033670
# 2025-02-09 22:00:00-05:00                    1.032585
# 2025-02-10 22:00:00-05:00                    1.032182
# 2025-02-11 22:00:00-05:00                    1.032559
#
# [78 rows x 2 columns]

# %%
df_leavitt[["Leavitt_Convolution_Computed", "Leavitt_Convolution_Dataset"]]
# Out:
#                            Leavitt_Convolution_Computed  \
# Date
# 2024-10-23 21:00:00-05:00                      1.087959
# 2024-10-24 21:00:00-05:00                      1.087959
# 2024-10-27 21:00:00-05:00                      1.087959
# 2024-10-28 21:00:00-05:00                      1.087959
# 2024-10-29 21:00:00-05:00                      1.087959
# ...                                                 ...
# 2025-02-05 22:00:00-05:00                      1.032029
# 2025-02-06 22:00:00-05:00                      1.032162
# 2025-02-09 22:00:00-05:00                      1.031537
# 2025-02-10 22:00:00-05:00                      1.031325
# 2025-02-11 22:00:00-05:00                      1.032416
#
#                            Leavitt_Convolution_Dataset
# Date
# 2024-10-23 21:00:00-05:00                     1.074185
# 2024-10-24 21:00:00-05:00                     1.074572
# 2024-10-27 21:00:00-05:00                     1.075442
# 2024-10-28 21:00:00-05:00                     1.076866
# 2024-10-29 21:00:00-05:00                     1.078942
# ...                                                ...
# 2025-02-05 22:00:00-05:00                     1.032029
# 2025-02-06 22:00:00-05:00                     1.032162
# 2025-02-09 22:00:00-05:00                     1.031537
# 2025-02-10 22:00:00-05:00                     1.031325
# 2025-02-11 22:00:00-05:00                     1.032416
#
# [78 rows x 2 columns]

# %%
df_leavitt[["LC_Slope_Computed", "LC_Slope_Dataset"]]
# Out:
#                            LC_Slope_Computed  LC_Slope_Dataset
# Date
# 2024-10-23 21:00:00-05:00                NaN         -0.001465
# 2024-10-24 21:00:00-05:00                NaN         -0.000713
# 2024-10-27 21:00:00-05:00      -1.909471e-16         -0.000083
# 2024-10-28 21:00:00-05:00      -1.909471e-16          0.000524
# 2024-10-29 21:00:00-05:00      -1.909471e-16          0.001140
# ...                                      ...               ...
# 2025-02-05 22:00:00-05:00      -2.439982e-03         -0.002440
# 2025-02-06 22:00:00-05:00      -1.388656e-03         -0.001389
# 2025-02-09 22:00:00-05:00      -1.057426e-03         -0.001057
# 2025-02-10 22:00:00-05:00      -7.435772e-04         -0.000744
# 2025-02-11 22:00:00-05:00      -1.307516e-05         -0.000013
#
# [78 rows x 2 columns]

# %%
df_leavitt[["LC_Intercept_Computed", "LC_Intercept_Dataset"]]
# Out:
#                            LC_Intercept_Computed  LC_Intercept_Dataset
# Date
# 2024-10-23 21:00:00-05:00                    NaN              1.078579
# 2024-10-24 21:00:00-05:00                    NaN              1.076710
# 2024-10-27 21:00:00-05:00               1.087959              1.075690
# 2024-10-28 21:00:00-05:00               1.087959              1.075293
# 2024-10-29 21:00:00-05:00               1.087959              1.075522
# ...                                          ...                   ...
# 2025-02-05 22:00:00-05:00               1.039349              1.039349
# 2025-02-06 22:00:00-05:00               1.036328              1.036328
# 2025-02-09 22:00:00-05:00               1.034709              1.034709
# 2025-02-10 22:00:00-05:00               1.033556              1.033556
# 2025-02-11 22:00:00-05:00               1.032455              1.032455
#
# [78 rows x 2 columns]

# %% [markdown]
# #### 🔹 Make sure all calculated fields above are equal.
#
# - This way we know how many look back bars need to be passed so our predictions are correct for our model
# ---

# %% [markdown]
# ## All the preamble above will let us know how many lookback bars are needed
#
# If we do not have enough bars to calculate all the features we will not be able to predict the values we need.
#
# We will now proceed to do a prediction from the model

# %% [markdown]
# #### 🔹 Step 1: Normalize or Scale
# - If you applied scaling (StandardScaler, MinMaxScaler) during training, apply the same here.

# %%
# Load the saved scaler
scaler_path = "../../artifacts/preprocessor.pkl"  # Adjust path
scaler = joblib.load(scaler_path)

print(df_cleaned.describe())

# Transform test data
X_predict = scaler.transform(df_cleaned)
# Out:
#               Volume       Open       High        Low      Close       AHMA  \
# count      78.000000  78.000000  78.000000  78.000000  78.000000  78.000000
# mean   158979.858974   1.050034   1.053723   1.045359   1.049511   1.049304
# std     48031.345766   0.017334   0.017146   0.017282   0.017086   0.016844
# min     55878.000000   1.024340   1.025010   1.017790   1.024340   1.025912
# 25%    132557.750000   1.037985   1.042588   1.034203   1.037497   1.037979
# 50%    160770.500000   1.048200   1.052290   1.041620   1.047060   1.046549
# 75%    178745.500000   1.056715   1.059658   1.052647   1.056607   1.053758
# max    398838.000000   1.092970   1.093740   1.087260   1.092970   1.088000
#
#        Leavitt_Projection  Leavitt_Convolution   LC_Slope  LC_Intercept  ...  \
# count           78.000000            78.000000  78.000000     78.000000  ...
# mean             1.048633             1.048046  -0.000582      1.049792  ...
# std              0.017553             0.017992   0.002610      0.018001  ...
# min              1.024600             1.024073  -0.007657      1.024216  ...
# 25%              1.035271             1.033832  -0.001739      1.036387  ...
# 50%              1.045268             1.044582  -0.000582      1.045447  ...
# 75%              1.055039             1.056008   0.001053      1.055633  ...
# max              1.088157             1.090368   0.004838      1.088485  ...
#
#        Returns_T-10  Momentum_T-10  Returns_T-21  Momentum_T-21       Hour  \
# count     78.000000      78.000000     78.000000      78.000000  78.000000
# mean      -0.000612       0.000129     -0.001029       0.000547  21.910256
# std        0.004969       0.007594      0.004641       0.007481   0.287664
# min       -0.018363      -0.016826     -0.018363      -0.018900  21.000000
# 25%       -0.002931      -0.005265     -0.003191      -0.004575  22.000000
# 50%       -0.001067       0.001223     -0.001428      -0.000166  22.000000
# 75%        0.001984       0.005245      0.001422       0.004609  22.000000
# max        0.014136       0.017616      0.007867       0.027661  22.000000
#
#        Day_Of_Week      Month         Year        ATR  Movement_Class
# count    78.000000  78.000000    78.000000  78.000000       78.000000
# mean      2.435897   7.435897  2024.384615   0.008150        0.961538
# std       2.086380   4.948015     0.489653   0.001232        0.763490
# min       0.000000   1.000000  2024.000000   0.005150        0.000000
# 25%       1.000000   1.000000  2024.000000   0.007729        0.000000
# 50%       2.000000  11.000000  2024.000000   0.008494        1.000000
# 75%       3.000000  12.000000  2025.000000   0.008896        2.000000
# max       6.000000  12.000000  2025.000000   0.010474        2.000000
#
# [8 rows x 29 columns]

# %%
print(df_cleaned.shape)
print(X_predict.shape)
# Out:
# (78, 29)
# (78, 47)

# %% [markdown]
# ✅ Ensures feature scaling is consistent for predicting.

# %% [markdown]
# #### 🔹Step 2: Load our saved model
#
# - This should be saved during the training phase

# %%
# Load trained model (XGBoost or CatBoost)
model_path = "../../artifacts/models/model.pkl"  # Adjust based on best model
model = joblib.load(model_path)

# %% [markdown]
# #### 🔹Step 3: Predict Direction
#
# - We assume the model predicts the direction

# %%
y_hat = model.predict(X_predict)

y_hat = y_hat.astype(int)
y_hat.shape
# Out:
# (78, 1)

# %% [markdown]
# #### 🔹Step 4: Calculate the probabilities
#
# - Also calculate the probabilites

# %%
y_proba = model.predict_proba(X_predict)
y_proba.shape
# Out:
# (78, 3)

# %% [markdown]
# #### 🔹Step 5: Get the probability of the prediction
#
# - The confidence of the y_hat value is the largest probability in the row
# - There are 3 classes and we have a column for each probability (think softmax)

# %%
y_confidence = y_proba.max(axis=1)
y_confidence.shape
# Out:
# (78,)

# %% [markdown]
# #### 🔹Step 6: Create a DataFrame

# %%
# Create DataFrame for predictions
df_predictions = pd.DataFrame(
    {
        "Predicted_Label": np.array(y_hat).flatten(),
        "Prediction_Confidence": np.array(y_confidence).flatten(),
    }
)

# %% [markdown]
# #### 🔹Step 7: Do with the data frame what you want

# %%
df_predictions.tail(1)
# Out:
#     Predicted_Label  Prediction_Confidence
# 77                1                0.73984

# %%
# Select the last N rows from df_lookback where N = number of predictions
df_lookback_subset = df_lookback.tail(len(df_predictions)).reset_index(drop=True)

# Reset index for df_predictions to ensure alignment
df_predictions = df_predictions.reset_index(drop=True)

# Merge datasets
df_lookback_subset = pd.concat([df_lookback_subset, df_predictions], axis=1)

# %%
df_lookback_subset.tail(20)
# Out:
#     Unnamed: 0                      time  volume    mid_o    mid_h    mid_l  \
# 58        1827 2025-01-15 22:00:00-05:00  160175  1.02904  1.03152  1.02608
# 59        1828 2025-01-16 22:00:00-05:00  141219  1.03020  1.03308  1.02653
# 60        1829 2025-01-19 22:00:00-05:00  187472  1.02718  1.04345  1.02664
# 61        1830 2025-01-20 22:00:00-05:00  214932  1.04170  1.04356  1.03417
# 62        1831 2025-01-21 22:00:00-05:00  148134  1.04290  1.04574  1.03922
# 63        1832 2025-01-22 22:00:00-05:00  165378  1.04102  1.04380  1.03721
# 64        1833 2025-01-23 22:00:00-05:00  174843  1.04156  1.05215  1.04116
# 65        1834 2025-01-26 22:00:00-05:00  178570  1.04953  1.05333  1.04539
# 66        1835 2025-01-27 22:00:00-05:00  166715  1.04921  1.04940  1.04138
# 67        1836 2025-01-28 22:00:00-05:00  173910  1.04307  1.04438  1.03824
# 68        1837 2025-01-29 22:00:00-05:00  169642  1.04200  1.04678  1.03862
# 69        1838 2025-01-30 22:00:00-05:00  217371  1.03923  1.04340  1.03500
# 70        1839 2025-02-02 22:00:00-05:00  332786  1.03606  1.03606  1.02105
# 71        1840 2025-02-03 22:00:00-05:00  178263  1.03428  1.03877  1.02719
# 72        1841 2025-02-04 22:00:00-05:00  156914  1.03788  1.04432  1.03696
# 73        1842 2025-02-05 22:00:00-05:00  136702  1.04028  1.04060  1.03526
# 74        1843 2025-02-06 22:00:00-05:00  183108  1.03830  1.04134  1.03052
# 75        1844 2025-02-09 22:00:00-05:00  112919  1.03270  1.03366  1.02838
# 76        1845 2025-02-10 22:00:00-05:00  119270  1.03070  1.03816  1.02922
# 77        1846 2025-02-11 22:00:00-05:00   55878  1.03612  1.03858  1.03540
#
#       mid_c    bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l  \
# 58  1.03020  1.02895  1.03144  1.02598  1.03012  1.02912  1.03159  1.02615
# 59  1.02718  1.03012  1.03300  1.02645  1.02683  1.03029  1.03316  1.02661
# 60  1.04170  1.02683  1.04338  1.02656  1.04161  1.02752  1.04353  1.02672
# 61  1.04290  1.04161  1.04347  1.03409  1.04244  1.04178  1.04364  1.03425
# 62  1.04102  1.04244  1.04566  1.03914  1.04092  1.04335  1.04582  1.03929
# 63  1.04156  1.04092  1.04373  1.03713  1.04147  1.04111  1.04388  1.03728
# 64  1.04953  1.04147  1.05207  1.04108  1.04903  1.04165  1.05223  1.04124
# 65  1.04921  1.04903  1.05325  1.04531  1.04912  1.05003  1.05342  1.04547
# 66  1.04307  1.04912  1.04927  1.04130  1.04299  1.04930  1.04958  1.04146
# 67  1.04200  1.04299  1.04431  1.03815  1.04192  1.04315  1.04445  1.03831
# 68  1.03923  1.04192  1.04670  1.03854  1.03913  1.04209  1.04686  1.03869
# 69  1.03606  1.03913  1.04332  1.03492  1.03576  1.03933  1.04350  1.03507
# 70  1.03428  1.03576  1.03576  1.02094  1.03418  1.03637  1.03637  1.02115
# 71  1.03788  1.03418  1.03870  1.02710  1.03781  1.03439  1.03884  1.02728
# 72  1.04028  1.03781  1.04423  1.03689  1.04019  1.03796  1.04440  1.03703
# 73  1.03830  1.04019  1.04052  1.03518  1.03820  1.04037  1.04071  1.03534
# 74  1.03270  1.03820  1.04123  1.03044  1.03261  1.03839  1.04146  1.03061
# 75  1.03070  1.03261  1.03358  1.02788  1.03062  1.03280  1.03373  1.02888
# 76  1.03612  1.03062  1.03808  1.02914  1.03604  1.03079  1.03825  1.02929
# 77  1.03737  1.03604  1.03850  1.03532  1.03729  1.03621  1.03865  1.03548
#
#       ask_c  Predicted_Label  Prediction_Confidence
# 58  1.03029                1               0.533388
# 59  1.02752                0               0.677034
# 60  1.04178                2               0.961520
# 61  1.04335                1               0.586455
# 62  1.04111                0               0.673860
# 63  1.04165                1               0.656375
# 64  1.05003                2               0.911999
# 65  1.04930                0               0.659874
# 66  1.04315                0               0.940875
# 67  1.04209                1               0.674367
# 68  1.03933                0               0.593802
# 69  1.03637                0               0.495551
# 70  1.03439                0               0.529894
# 71  1.03796                2               0.649994
# 72  1.04037                2               0.635341
# 73  1.03839                0               0.580402
# 74  1.03280                0               0.947176
# 75  1.03079                1               0.603804
# 76  1.03621                2               0.910548
# 77  1.03745                1               0.739840
